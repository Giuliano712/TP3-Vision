# %% [markdown]
# ## Imports

# %%
import sys
from datetime import datetime
import os

import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import pandas as pd
import torchvision
import torchvision.transforms as transforms
from torch import optim

from torchvision import models

from sklearn.metrics import accuracy_score, balanced_accuracy_score, f1_score, cohen_kappa_score, \
    top_k_accuracy_score, confusion_matrix, classification_report

import plotly.express as px

# %% [markdown]
# ## Download the dataset

# %%
from google.colab import userdata
import os

os.environ["KAGGLE_KEY"] = userdata.get('KAGGLE_KEY')
os.environ["KAGGLE_USERNAME"] = userdata.get('KAGGLE_USERNAME')

# %%
# !kaggle datasets download -d gpiosenka/cards-image-datasetclassification

! unzip "cards-image-datasetclassification.zip" -d "data"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/train/jack of spades/059.jpg
#   inflating: data/train/jack of spades/060.jpg
#   inflating: data/train/jack of spades/061.jpg
#   inflating: data/train/jack of spades/062.jpg
#   inflating: data/train/jack of spades/063.jpg
#   inflating: data/train/jack of spades/064.jpg
#   inflating: data/train/jack of spades/065.jpg
#   inflating: data/train/jack of spades/066.jpg
#   inflating: data/train/jack of spades/067.jpg
#   inflating: data/train/jack of spades/068.jpg
#   inflating: data/train/jack of spades/069.jpg
#   inflating: data/train/jack of spades/070.jpg
#   inflating: data/train/jack of spades/071.jpg
#   inflating: data/train/jack of spades/072.jpg
#   inflating: data/train/jack of spades/073.jpg
#   inflating: data/train/jack of spades/074.jpg
#   inflating: data/train/jack of spades/075.jpg
#   inflating: data/train/jack of spades/076.jpg
#   inflating: data/train/jack of spades/077.jpg
#   inflating: data/train/jack of spades/078.jpg
#   inflating: data/train/jack of spades/079.jpg
#   inflating: data/train/jack of spades/080.jpg
#   inflating: data/train/jack of spades/081.jpg
#   inflating: data/train/jack of spades/082.jpg
#   inflating: data/train/jack of spades/083.jpg
#   inflating: data/train/jack of spades/084.jpg
#   inflating: data/train/jack of spades/085.jpg
#   inflating: data/train/jack of spades/086.jpg
#   inflating: data/train/jack of spades/087.jpg
#   inflating: data/train/jack of spades/088.jpg
#   inflating: data/train/jack of spades/089.jpg
#   inflating: data/train/jack of spades/090.jpg
#   inflating: data/train/jack of spades/091.jpg
#   inflating: data/train/jack of spades/092.jpg
#   inflating: data/train/jack of spades/093.jpg
#   inflating: data/train/jack of spades/094.jpg
#   inflating: data/train/jack of spades/095.jpg
#   inflating: data/train/jack of spades/096.jpg
#   inflating: data/train/jack of spades/097.jpg
#   inflating: data/train/jack of spades/098.jpg
#   inflating: data/train/jack of spades/099.jpg
#   inflating: data/train/jack of spades/100.jpg
#   inflating: data/train/jack of spades/101.jpg
#   inflating: data/train/jack of spades/102.jpg
#   inflating: data/train/jack of spades/103.jpg
#   inflating: data/train/jack of spades/104.jpg
#   inflating: data/train/jack of spades/105.jpg
#   inflating: data/train/jack of spades/106.jpg
#   inflating: data/train/jack of spades/107.jpg
#   inflating: data/train/jack of spades/108.jpg
#   inflating: data/train/jack of spades/109.jpg
#   inflating: data/train/jack of spades/110.jpg
#   inflating: data/train/jack of spades/111.jpg
#   inflating: data/train/jack of spades/112.jpg
#   inflating: data/train/jack of spades/113.jpg
#   inflating: data/train/jack of spades/114.jpg
#   inflating: data/train/jack of spades/115.jpg
#   inflating: data/train/jack of spades/116.jpg
#   inflating: data/train/jack of spades/117.jpg
#   inflating: data/train/jack of spades/118.jpg
#   inflating: data/train/jack of spades/119.jpg
#   inflating: data/train/jack of spades/120.jpg
#   inflating: data/train/jack of spades/121.jpg
#   inflating: data/train/jack of spades/122.jpg
#   inflating: data/train/jack of spades/123.jpg
#   inflating: data/train/jack of spades/124.jpg
#   inflating: data/train/jack of spades/125.jpg
#   inflating: data/train/jack of spades/126.jpg
#   inflating: data/train/jack of spades/127.jpg
#   inflating: data/train/jack of spades/128.jpg
#   inflating: data/train/jack of spades/129.jpg
#   inflating: data/train/jack of spades/130.jpg
#   inflating: data/train/jack of spades/131.jpg
#   inflating: data/train/jack of spades/132.jpg
#   inflating: data/train/jack of spades/133.jpg
#   inflating: data/train/jack of spades/134.jpg
#   inflating: data/train/jack of spades/135.jpg
#   inflating: data/train/jack of spades/136.jpg
#   inflating: data/train/jack of spades/137.jpg
#   inflating: data/train/jack of spades/138.jpg
#   inflating: data/train/jack of spades/139.jpg
#   inflating: data/train/jack of spades/140.jpg
#   inflating: data/train/jack of spades/141.jpg
#   inflating: data/train/jack of spades/142.jpg
#   inflating: data/train/jack of spades/143.jpg
#   inflating: data/train/jack of spades/144.jpg
#   inflating: data/train/jack of spades/145.jpg
#   inflating: data/train/jack of spades/146.jpg
#   inflating: data/train/jack of spades/147.jpg
#   inflating: data/train/jack of spades/148.jpg
#   inflating: data/train/jack of spades/149.jpg
#   inflating: data/train/jack of spades/150.jpg
#   inflating: data/train/jack of spades/151.jpg
#   inflating: data/train/jack of spades/152.jpg
#   inflating: data/train/jack of spades/153.jpg
#   inflating: data/train/jack of spades/154.jpg
#   inflating: data/train/jack of spades/155.jpg
#   inflating: data/train/jack of spades/156.jpg
#   inflating: data/train/jack of spades/157.jpg
#   inflating: data/train/jack of spades/158.jpg
#   inflating: data/train/jack of spades/159.jpg
#   inflating: data/train/jack of spades/160.jpg
#   inflating: data/train/jack of spades/161.jpg
#   inflating: data/train/jack of spades/162.jpg
#   inflating: data/train/jack of spades/163.jpg
#   inflating: data/train/jack of spades/164.jpg
#   inflating: data/train/jack of spades/165.jpg
#   inflating: data/train/jack of spades/166.jpg
#   inflating: data/train/jack of spades/167.jpg
#   inflating: data/train/jack of spades/168.jpg
#   inflating: data/train/jack of spades/169.jpg
#   inflating: data/train/jack of spades/170.jpg
#   inflating: data/train/jack of spades/171.jpg
#   inflating: data/train/jack of spades/172.jpg
#   inflating: data/train/joker/001.jpg
#   inflating: data/train/joker/002.jpg
#   inflating: data/train/joker/003.jpg
#   inflating: data/train/joker/004.jpg
#   inflating: data/train/joker/005.jpg
#   inflating: data/train/joker/006.jpg
#   inflating: data/train/joker/007.jpg
#   inflating: data/train/joker/008.jpg
#   inflating: data/train/joker/009.jpg
#   inflating: data/train/joker/010.jpg
#   inflating: data/train/joker/011.jpg
#   inflating: data/train/joker/012.jpg
#   inflating: data/train/joker/013.jpg
#   inflating: data/train/joker/014.jpg
#   inflating: data/train/joker/015.jpg
#   inflating: data/train/joker/016.jpg
#   inflating: data/train/joker/017.jpg
#   inflating: data/train/joker/018.jpg
#   inflating: data/train/joker/019.jpg
#   inflating: data/train/joker/020.jpg
#   inflating: data/train/joker/021.jpg
#   inflating: data/train/joker/022.jpg
#   inflating: data/train/joker/023.jpg
#   inflating: data/train/joker/024.jpg
#   inflating: data/train/joker/025.jpg
#   inflating: data/train/joker/026.jpg
#   inflating: data/train/joker/027.jpg
#   inflating: data/train/joker/028.jpg
#   inflating: data/train/joker/029.jpg
#   inflating: data/train/joker/030.jpg
#   inflating: data/train/joker/031.jpg
#   inflating: data/train/joker/032.jpg
#   inflating: data/train/joker/033.jpg
#   inflating: data/train/joker/034.jpg
#   inflating: data/train/joker/035.jpg
#   inflating: data/train/joker/036.jpg
#   inflating: data/train/joker/037.jpg
#   inflating: data/train/joker/038.jpg
#   inflating: data/train/joker/039.jpg
#   inflating: data/train/joker/040.jpg
#   inflating: data/train/joker/041.jpg
#   inflating: data/train/joker/042.jpg
#   inflating: data/train/joker/043.jpg
#   inflating: data/train/joker/044.jpg
#   inflating: data/train/joker/045.jpg
#   inflating: data/train/joker/046.jpg
#   inflating: data/train/joker/047.jpg
#   inflating: data/train/joker/048.jpg
#   inflating: data/train/joker/049.jpg
#   inflating: data/train/joker/050.jpg
#   inflating: data/train/joker/051.jpg
#   inflating: data/train/joker/052.jpg
#   inflating: data/train/joker/053.jpg
#   inflating: data/train/joker/054.jpg
#   inflating: data/train/joker/055.jpg
#   inflating: data/train/joker/056.jpg
#   inflating: data/train/joker/057.jpg
#   inflating: data/train/joker/058.jpg
#   inflating: data/train/joker/059.jpg
#   inflating: data/train/joker/060.jpg
#   inflating: data/train/joker/061.jpg
#   inflating: data/train/joker/062.jpg
#   inflating: data/train/joker/063.jpg
#   inflating: data/train/joker/064.jpg
#   inflating: data/train/joker/065.jpg
#   inflating: data/train/joker/066.jpg
#   inflating: data/train/joker/067.jpg
#   inflating: data/train/joker/068.jpg
#   inflating: data/train/joker/069.jpg
#   inflating: data/train/joker/070.jpg
#   inflating: data/train/joker/071.jpg
#   inflating: data/train/joker/072.jpg
#   inflating: data/train/joker/073.jpg
#   inflating: data/train/joker/074.jpg
#   inflating: data/train/joker/075.jpg
#   inflating: data/train/joker/076.jpg
#   inflating: data/train/joker/077.jpg
#   inflating: data/train/joker/078.jpg
#   inflating: data/train/joker/079.jpg
#   inflating: data/train/joker/080.jpg
#   inflating: data/train/joker/081.jpg
#   inflating: data/train/joker/082.jpg
#   inflating: data/train/joker/083.jpg
#   inflating: data/train/joker/084.jpg
#   inflating: data/train/joker/085.jpg
#   inflating: data/train/joker/086.jpg
#   inflating: data/train/joker/087.jpg
#   inflating: data/train/joker/088.jpg
#   inflating: data/train/joker/089.jpg
#   inflating: data/train/joker/090.jpg
#   inflating: data/train/joker/091.jpg
#   inflating: data/train/joker/092.jpg
#   inflating: data/train/joker/093.jpg
#   inflating: data/train/joker/094.jpg
#   inflating: data/train/joker/095.jpg
#   inflating: data/train/joker/096.jpg
#   inflating: data/train/joker/097.jpg
#   inflating: data/train/joker/098.jpg
#   inflating: data/train/joker/099.jpg
#   inflating: data/train/joker/100.jpg
#   inflating: data/train/joker/101.jpg
#   inflating: data/train/joker/102.jpg
#   inflating: data/train/joker/103.jpg
#   inflating: data/train/joker/104.jpg
#   inflating: data/train/joker/105.jpg
#   inflating: data/train/joker/106.jpg
#   inflating: data/train/joker/107.jpg
#   inflating: data/train/joker/108.jpg
#   inflating: data/train/joker/109.jpg
#   inflating: data/train/joker/110.jpg
#   inflating: data/train/joker/111.jpg
#   inflating: data/train/joker/112.jpg
#   inflating: data/train/joker/113.jpg
#   inflating: data/train/joker/114.jpg
#   inflating: data/train/joker/115.jpg
#   inflating: data/train/king of clubs/001.jpg
#   inflating: data/train/king of clubs/002.jpg
#   inflating: data/train/king of clubs/003.jpg
#   inflating: data/train/king of clubs/004.jpg
#   inflating: data/train/king of clubs/005.jpg
#   inflating: data/train/king of clubs/006.jpg
#   inflating: data/train/king of clubs/007.jpg
#   inflating: data/train/king of clubs/008.jpg
#   inflating: data/train/king of clubs/009.jpg
#   inflating: data/train/king of clubs/010.jpg
#   inflating: data/train/king of clubs/011.jpg
#   inflating: data/train/king of clubs/012.jpg
#   inflating: data/train/king of clubs/013.jpg
#   inflating: data/train/king of clubs/014.jpg
#   inflating: data/train/king of clubs/015.jpg
#   inflating: data/train/king of clubs/016.jpg
#   inflating: data/train/king of clubs/017.jpg
#   inflating: data/train/king of clubs/018.jpg
#   inflating: data/train/king of clubs/019.jpg
#   inflating: data/train/king of clubs/020.jpg
#   inflating: data/train/king of clubs/021.jpg
#   inflating: data/train/king of clubs/022.jpg
#   inflating: data/train/king of clubs/023.jpg
#   inflating: data/train/king of clubs/024.jpg
#   inflating: data/train/king of clubs/025.jpg
#   inflating: data/train/king of clubs/026.jpg
#   inflating: data/train/king of clubs/027.jpg
#   inflating: data/train/king of clubs/028.jpg
#   inflating: data/train/king of clubs/029.jpg
#   inflating: data/train/king of clubs/030.jpg
#   inflating: data/train/king of clubs/031.jpg
#   inflating: data/train/king of clubs/032.jpg
#   inflating: data/train/king of clubs/033.jpg
#   inflating: data/train/king of clubs/034.jpg
#   inflating: data/train/king of clubs/035.jpg
#   inflating: data/train/king of clubs/036.jpg
#   inflating: data/train/king of clubs/037.jpg
#   inflating: data/train/king of clubs/038.jpg
#   inflating: data/train/king of clubs/039.jpg
#   inflating: data/train/king of clubs/040.jpg
#   inflating: data/train/king of clubs/041.jpg
#   inflating: data/train/king of clubs/042.jpg
#   inflating: data/train/king of clubs/043.jpg
#   inflating: data/train/king of clubs/044.jpg
#   inflating: data/train/king of clubs/045.jpg
#   inflating: data/train/king of clubs/046.jpg
#   inflating: data/train/king of clubs/047.jpg
#   inflating: data/train/king of clubs/048.jpg
#   inflating: data/train/king of clubs/049.jpg
#   inflating: data/train/king of clubs/050.jpg
#   inflating: data/train/king of clubs/051.jpg
#   inflating: data/train/king of clubs/052.jpg
#   inflating: data/train/king of clubs/053.jpg
#   inflating: data/train/king of clubs/054.jpg
#   inflating: data/train/king of clubs/055.jpg
#   inflating: data/train/king of clubs/056.jpg
#   inflating: data/train/king of clubs/057.jpg
#   inflating: data/train/king of clubs/058.jpg
#   inflating: data/train/king of clubs/059.jpg
#   inflating: data/train/king of clubs/060.jpg
#   inflating: data/train/king of clubs/061.jpg
#   inflating: data/train/king of clubs/062.jpg
#   inflating: data/train/king of clubs/063.jpg
#   inflating: data/train/king of clubs/064.jpg
#   inflating: data/train/king of clubs/065.jpg
#   inflating: data/train/king of clubs/066.jpg
#   inflating: data/train/king of clubs/067.jpg
#   inflating: data/train/king of clubs/068.jpg
#   inflating: data/train/king of clubs/069.jpg
#   inflating: data/train/king of clubs/070.jpg
#   inflating: data/train/king of clubs/071.jpg
#   inflating: data/train/king of clubs/072.jpg
#   inflating: data/train/king of clubs/073.jpg
#   inflating: data/train/king of clubs/074.jpg
#   inflating: data/train/king of clubs/075.jpg
#   inflating: data/train/king of clubs/076.jpg
#   inflating: data/train/king of clubs/077.jpg
#   inflating: data/train/king of clubs/078.jpg
#   inflating: data/train/king of clubs/079.jpg
#   inflating: data/train/king of clubs/080.jpg
#   inflating: data/train/king of clubs/081.jpg
#   inflating: data/train/king of clubs/082.jpg
#   inflating: data/train/king of clubs/083.jpg
#   inflating: data/train/king of clubs/084.jpg
#   inflating: data/train/king of clubs/085.jpg
#   inflating: data/train/king of clubs/086.jpg
#   inflating: data/train/king of clubs/087.jpg
#   inflating: data/train/king of clubs/088.jpg
#   inflating: data/train/king of clubs/089.jpg
#   inflating: data/train/king of clubs/090.jpg
#   inflating: data/train/king of clubs/091.jpg
#   inflating: data/train/king of clubs/092.jpg
#   inflating: data/train/king of clubs/093.jpg
#   inflating: data/train/king of clubs/094.jpg
#   inflating: data/train/king of clubs/095.jpg
#   inflating: data/train/king of clubs/096.jpg
#   inflating: data/train/king of clubs/097.jpg
#   inflating: data/train/king of clubs/098.jpg
#   inflating: data/train/king of clubs/099.jpg
#   inflating: data/train/king of clubs/100.jpg
#   inflating: data/train/king of clubs/101.jpg
#   inflating: data/train/king of clubs/102.jpg
#   inflating: data/train/king of clubs/103.jpg
#   inflating: data/train/king of clubs/104.jpg
#   inflating: data/train/king of clubs/105.jpg
#   inflating: data/train/king of clubs/106.jpg
#   inflating: data/train/king of clubs/107.jpg
#   inflating: data/train/king of clubs/108.jpg
#   inflating: data/train/king of clubs/109.jpg
#   inflating: data/train/king of clubs/110.jpg
#   inflating: data/train/king of clubs/111.jpg
#   inflating: data/train/king of clubs/112.jpg
#   inflating: data/train/king of clubs/113.jpg
#   inflating: data/train/king of clubs/114.jpg
#   inflating: data/train/king of clubs/115.jpg
#   inflating: data/train/king of clubs/116.jpg
#   inflating: data/train/king of clubs/117.jpg
#   inflating: data/train/king of clubs/118.jpg
#   inflating: data/train/king of clubs/119.jpg
#   inflating: data/train/king of clubs/120.jpg
#   inflating: data/train/king of clubs/121.jpg
#   inflating: data/train/king of clubs/122.jpg
#   inflating: data/train/king of clubs/123.jpg
#   inflating: data/train/king of clubs/124.jpg
#   inflating: data/train/king of clubs/125.jpg
#   inflating: data/train/king of clubs/126.jpg
#   inflating: data/train/king of clubs/127.jpg
#   inflating: data/train/king of clubs/128.jpg
#   inflating: data/train/king of diamonds/001.jpg
#   inflating: data/train/king of diamonds/002.jpg
#   inflating: data/train/king of diamonds/003.jpg
#   inflating: data/train/king of diamonds/004.jpg
#   inflating: data/train/king of diamonds/005.jpg
#   inflating: data/train/king of diamonds/006.jpg
#   inflating: data/train/king of diamonds/007.jpg
#   inflating: data/train/king of diamonds/008.jpg
#   inflating: data/train/king of diamonds/009.jpg
#   inflating: data/train/king of diamonds/010.jpg
#   inflating: data/train/king of diamonds/011.jpg
#   inflating: data/train/king of diamonds/012.jpg
#   inflating: data/train/king of diamonds/013.jpg
#   inflating: data/train/king of diamonds/014.jpg
#   inflating: data/train/king of diamonds/015.jpg
#   inflating: data/train/king of diamonds/016.jpg
#   inflating: data/train/king of diamonds/017.jpg
#   inflating: data/train/king of diamonds/018.jpg
#   inflating: data/train/king of diamonds/019.jpg
#   inflating: data/train/king of diamonds/020.jpg
#   inflating: data/train/king of diamonds/021.jpg
#   inflating: data/train/king of diamonds/022.jpg
#   inflating: data/train/king of diamonds/023.jpg
#   inflating: data/train/king of diamonds/024.jpg
#   inflating: data/train/king of diamonds/025.jpg
#   inflating: data/train/king of diamonds/026.jpg
#   inflating: data/train/king of diamonds/027.jpg
#   inflating: data/train/king of diamonds/028.jpg
#   inflating: data/train/king of diamonds/029.jpg
#   inflating: data/train/king of diamonds/030.jpg
#   inflating: data/train/king of diamonds/031.jpg
#   inflating: data/train/king of diamonds/032.jpg
#   inflating: data/train/king of diamonds/033.jpg
#   inflating: data/train/king of diamonds/034.jpg
#   inflating: data/train/king of diamonds/035.jpg
#   inflating: data/train/king of diamonds/036.jpg
#   inflating: data/train/king of diamonds/037.jpg
#   inflating: data/train/king of diamonds/038.jpg
#   inflating: data/train/king of diamonds/039.jpg
#   inflating: data/train/king of diamonds/040.jpg
#   inflating: data/train/king of diamonds/041.jpg
#   inflating: data/train/king of diamonds/042.jpg
#   inflating: data/train/king of diamonds/043.jpg
#   inflating: data/train/king of diamonds/044.jpg
#   inflating: data/train/king of diamonds/045.jpg
#   inflating: data/train/king of diamonds/046.jpg
#   inflating: data/train/king of diamonds/047.jpg
#   inflating: data/train/king of diamonds/048.jpg
#   inflating: data/train/king of diamonds/049.jpg
#   inflating: data/train/king of diamonds/050.jpg
#   inflating: data/train/king of diamonds/051.jpg
#   inflating: data/train/king of diamonds/052.jpg
#   inflating: data/train/king of diamonds/053.jpg
#   inflating: data/train/king of diamonds/054.jpg
#   inflating: data/train/king of diamonds/055.jpg
#   inflating: data/train/king of diamonds/056.jpg
#   inflating: data/train/king of diamonds/057.jpg
#   inflating: data/train/king of diamonds/058.jpg
#   inflating: data/train/king of diamonds/059.jpg
#   inflating: data/train/king of diamonds/060.jpg
#   inflating: data/train/king of diamonds/061.jpg
#   inflating: data/train/king of diamonds/062.jpg
#   inflating: data/train/king of diamonds/063.jpg
#   inflating: data/train/king of diamonds/064.jpg
#   inflating: data/train/king of diamonds/065.jpg
#   inflating: data/train/king of diamonds/066.jpg
#   inflating: data/train/king of diamonds/067.jpg
#   inflating: data/train/king of diamonds/068.jpg
#   inflating: data/train/king of diamonds/069.jpg
#   inflating: data/train/king of diamonds/070.jpg
#   inflating: data/train/king of diamonds/071.jpg
#   inflating: data/train/king of diamonds/072.jpg
#   inflating: data/train/king of diamonds/073.jpg
#   inflating: data/train/king of diamonds/074.jpg
#   inflating: data/train/king of diamonds/075.jpg
#   inflating: data/train/king of diamonds/076.jpg
#   inflating: data/train/king of diamonds/077.jpg
#   inflating: data/train/king of diamonds/078.jpg
#   inflating: data/train/king of diamonds/079.jpg
#   inflating: data/train/king of diamonds/080.jpg
#   inflating: data/train/king of diamonds/081.jpg
#   inflating: data/train/king of diamonds/082.jpg
#   inflating: data/train/king of diamonds/083.jpg
#   inflating: data/train/king of diamonds/084.jpg
#   inflating: data/train/king of diamonds/085.jpg
#   inflating: data/train/king of diamonds/086.jpg
#   inflating: data/train/king of diamonds/087.jpg
#   inflating: data/train/king of diamonds/088.jpg
#   inflating: data/train/king of diamonds/089.jpg
#   inflating: data/train/king of diamonds/090.jpg
#   inflating: data/train/king of diamonds/091.jpg
#   inflating: data/train/king of diamonds/092.jpg
#   inflating: data/train/king of diamonds/093.jpg
#   inflating: data/train/king of diamonds/094.jpg
#   inflating: data/train/king of diamonds/095.jpg
#   inflating: data/train/king of diamonds/096.jpg
#   inflating: data/train/king of diamonds/097.jpg
#   inflating: data/train/king of diamonds/098.jpg
#   inflating: data/train/king of diamonds/099.jpg
#   inflating: data/train/king of diamonds/100.jpg
#   inflating: data/train/king of diamonds/101.jpg
#   inflating: data/train/king of diamonds/102.jpg
#   inflating: data/train/king of diamonds/103.jpg
#   inflating: data/train/king of diamonds/104.jpg
#   inflating: data/train/king of diamonds/105.jpg
#   inflating: data/train/king of diamonds/106.jpg
#   inflating: data/train/king of diamonds/107.jpg
#   inflating: data/train/king of diamonds/108.jpg
#   inflating: data/train/king of diamonds/109.jpg
#   inflating: data/train/king of diamonds/110.jpg
#   inflating: data/train/king of diamonds/111.jpg
#   inflating: data/train/king of diamonds/112.jpg
#   inflating: data/train/king of diamonds/113.jpg
#   inflating: data/train/king of diamonds/114.jpg
#   inflating: data/train/king of diamonds/115.jpg
#   inflating: data/train/king of diamonds/116.jpg
#   inflating: data/train/king of diamonds/117.jpg
#   inflating: data/train/king of diamonds/118.jpg
#   inflating: data/train/king of diamonds/119.jpg
#   inflating: data/train/king of diamonds/120.jpg
#   inflating: data/train/king of diamonds/121.jpg
#   inflating: data/train/king of diamonds/122.jpg
#   inflating: data/train/king of diamonds/123.jpg
#   inflating: data/train/king of diamonds/124.jpg
#   inflating: data/train/king of diamonds/125.jpg
#   inflating: data/train/king of diamonds/126.jpg
#   inflating: data/train/king of diamonds/127.jpg
#   inflating: data/train/king of diamonds/128.jpg
#   inflating: data/train/king of diamonds/129.jpg
#   inflating: data/train/king of diamonds/130.jpg
#   inflating: data/train/king of diamonds/131.jpg
#   inflating: data/train/king of diamonds/132.jpg
#   inflating: data/train/king of diamonds/133.jpg
#   inflating: data/train/king of diamonds/134.jpg
#   inflating: data/train/king of diamonds/135.jpg
#   inflating: data/train/king of hearts/001.jpg
#   inflating: data/train/king of hearts/002.jpg
#   inflating: data/train/king of hearts/003.jpg
#   inflating: data/train/king of hearts/004.jpg
#   inflating: data/train/king of hearts/005.jpg
#   inflating: data/train/king of hearts/006.jpg
#   inflating: data/train/king of hearts/007.jpg
#   inflating: data/train/king of hearts/008.jpg
#   inflating: data/train/king of hearts/009.jpg
#   inflating: data/train/king of hearts/010.jpg
#   inflating: data/train/king of hearts/011.jpg
#   inflating: data/train/king of hearts/012.jpg
#   inflating: data/train/king of hearts/013.jpg
#   inflating: data/train/king of hearts/014.jpg
#   inflating: data/train/king of hearts/015.jpg
#   inflating: data/train/king of hearts/016.jpg
#   inflating: data/train/king of hearts/017.jpg
#   inflating: data/train/king of hearts/018.jpg
#   inflating: data/train/king of hearts/019.jpg
#   inflating: data/train/king of hearts/020.jpg
#   inflating: data/train/king of hearts/021.jpg
#   inflating: data/train/king of hearts/022.jpg
#   inflating: data/train/king of hearts/023.jpg
#   inflating: data/train/king of hearts/024.jpg
#   inflating: data/train/king of hearts/025.jpg
#   inflating: data/train/king of hearts/026.jpg
#   inflating: data/train/king of hearts/027.jpg
#   inflating: data/train/king of hearts/028.jpg
#   inflating: data/train/king of hearts/029.jpg
#   inflating: data/train/king of hearts/030.jpg
#   inflating: data/train/king of hearts/031.jpg
#   inflating: data/train/king of hearts/032.jpg
#   inflating: data/train/king of hearts/033.jpg
#   inflating: data/train/king of hearts/034.jpg
#   inflating: data/train/king of hearts/035.jpg
#   inflating: data/train/king of hearts/036.jpg
#   inflating: data/train/king of hearts/037.jpg
#   inflating: data/train/king of hearts/038.jpg
#   inflating: data/train/king of hearts/039.jpg
#   inflating: data/train/king of hearts/040.jpg
#   inflating: data/train/king of hearts/041.jpg
#   inflating: data/train/king of hearts/042.jpg
#   inflating: data/train/king of hearts/043.jpg
#   inflating: data/train/king of hearts/044.jpg
#   inflating: data/train/king of hearts/045.jpg
#   inflating: data/train/king of hearts/046.jpg
#   inflating: data/train/king of hearts/047.jpg
#   inflating: data/train/king of hearts/048.jpg
#   inflating: data/train/king of hearts/049.jpg
#   inflating: data/train/king of hearts/050.jpg
#   inflating: data/train/king of hearts/051.jpg
#   inflating: data/train/king of hearts/052.jpg
#   inflating: data/train/king of hearts/053.jpg
#   inflating: data/train/king of hearts/054.jpg
#   inflating: data/train/king of hearts/055.jpg
#   inflating: data/train/king of hearts/056.jpg
#   inflating: data/train/king of hearts/057.jpg
#   inflating: data/train/king of hearts/058.jpg
#   inflating: data/train/king of hearts/059.jpg
#   inflating: data/train/king of hearts/060.jpg
#   inflating: data/train/king of hearts/061.jpg
#   inflating: data/train/king of hearts/062.jpg
#   inflating: data/train/king of hearts/063.jpg
#   inflating: data/train/king of hearts/064.jpg
#   inflating: data/train/king of hearts/065.jpg
#   inflating: data/train/king of hearts/066.jpg
#   inflating: data/train/king of hearts/067.jpg
#   inflating: data/train/king of hearts/068.jpg
#   inflating: data/train/king of hearts/069.jpg
#   inflating: data/train/king of hearts/070.jpg
#   inflating: data/train/king of hearts/071.jpg
#   inflating: data/train/king of hearts/072.jpg
#   inflating: data/train/king of hearts/073.jpg
#   inflating: data/train/king of hearts/074.jpg
#   inflating: data/train/king of hearts/075.jpg
#   inflating: data/train/king of hearts/076.jpg
#   inflating: data/train/king of hearts/077.jpg
#   inflating: data/train/king of hearts/078.jpg
#   inflating: data/train/king of hearts/079.jpg
#   inflating: data/train/king of hearts/080.jpg
#   inflating: data/train/king of hearts/081.jpg
#   inflating: data/train/king of hearts/082.jpg
#   inflating: data/train/king of hearts/083.jpg
#   inflating: data/train/king of hearts/084.jpg
#   inflating: data/train/king of hearts/085.jpg
#   inflating: data/train/king of hearts/086.jpg
#   inflating: data/train/king of hearts/087.jpg
#   inflating: data/train/king of hearts/088.jpg
#   inflating: data/train/king of hearts/089.jpg
#   inflating: data/train/king of hearts/090.jpg
#   inflating: data/train/king of hearts/091.jpg
#   inflating: data/train/king of hearts/092.jpg
#   inflating: data/train/king of hearts/093.jpg
#   inflating: data/train/king of hearts/094.jpg
#   inflating: data/train/king of hearts/095.jpg
#   inflating: data/train/king of hearts/096.jpg
#   inflating: data/train/king of hearts/097.jpg
#   inflating: data/train/king of hearts/098.jpg
#   inflating: data/train/king of hearts/099.jpg
#   inflating: data/train/king of hearts/100.jpg
#   inflating: data/train/king of hearts/101.jpg
#   inflating: data/train/king of hearts/102.jpg
#   inflating: data/train/king of hearts/103.jpg
#   inflating: data/train/king of hearts/104.jpg
#   inflating: data/train/king of hearts/105.jpg
#   inflating: data/train/king of hearts/106.jpg
#   inflating: data/train/king of hearts/107.jpg
#   inflating: data/train/king of hearts/108.jpg
#   inflating: data/train/king of hearts/109.jpg
#   inflating: data/train/king of hearts/110.jpg
#   inflating: data/train/king of hearts/111.jpg
#   inflating: data/train/king of hearts/112.jpg
#   inflating: data/train/king of hearts/113.jpg
#   inflating: data/train/king of hearts/114.jpg
#   inflating: data/train/king of hearts/115.jpg
#   inflating: data/train/king of hearts/116.jpg
#   inflating: data/train/king of hearts/117.jpg
#   inflating: data/train/king of hearts/118.jpg
#   inflating: data/train/king of hearts/119.jpg
#   inflating: data/train/king of hearts/120.jpg
#   inflating: data/train/king of hearts/121.jpg
#   inflating: data/train/king of hearts/122.jpg
#   inflating: data/train/king of hearts/123.jpg
#   inflating: data/train/king of hearts/124.jpg
#   inflating: data/train/king of hearts/125.jpg
#   inflating: data/train/king of spades/001.jpg
#   inflating: data/train/king of spades/002.jpg
#   inflating: data/train/king of spades/003.jpg
#   inflating: data/train/king of spades/004.jpg
#   inflating: data/train/king of spades/005.jpg
#   inflating: data/train/king of spades/006.jpg
#   inflating: data/train/king of spades/007.jpg
#   inflating: data/train/king of spades/008.jpg
#   inflating: data/train/king of spades/009.jpg
#   inflating: data/train/king of spades/010.jpg
#   inflating: data/train/king of spades/011.jpg
#   inflating: data/train/king of spades/012.jpg
#   inflating: data/train/king of spades/013.jpg
#   inflating: data/train/king of spades/014.jpg
#   inflating: data/train/king of spades/015.jpg
#   inflating: data/train/king of spades/016.jpg
#   inflating: data/train/king of spades/017.jpg
#   inflating: data/train/king of spades/018.jpg
#   inflating: data/train/king of spades/019.jpg
#   inflating: data/train/king of spades/020.jpg
#   inflating: data/train/king of spades/021.jpg
#   inflating: data/train/king of spades/022.jpg
#   inflating: data/train/king of spades/023.jpg
#   inflating: data/train/king of spades/024.jpg
#   inflating: data/train/king of spades/025.jpg
#   inflating: data/train/king of spades/026.jpg
#   inflating: data/train/king of spades/027.jpg
#   inflating: data/train/king of spades/028.jpg
#   inflating: data/train/king of spades/029.jpg
#   inflating: data/train/king of spades/030.jpg
#   inflating: data/train/king of spades/031.jpg
#   inflating: data/train/king of spades/032.jpg
#   inflating: data/train/king of spades/033.jpg
#   inflating: data/train/king of spades/034.jpg
#   inflating: data/train/king of spades/035.jpg
#   inflating: data/train/king of spades/036.jpg
#   inflating: data/train/king of spades/037.jpg
#   inflating: data/train/king of spades/038.jpg
#   inflating: data/train/king of spades/039.jpg
#   inflating: data/train/king of spades/040.jpg
#   inflating: data/train/king of spades/041.jpg
#   inflating: data/train/king of spades/042.jpg
#   inflating: data/train/king of spades/043.jpg
#   inflating: data/train/king of spades/044.jpg
#   inflating: data/train/king of spades/045.jpg
#   inflating: data/train/king of spades/046.jpg
#   inflating: data/train/king of spades/047.jpg
#   inflating: data/train/king of spades/048.jpg
#   inflating: data/train/king of spades/049.jpg
#   inflating: data/train/king of spades/050.jpg
#   inflating: data/train/king of spades/051.jpg
#   inflating: data/train/king of spades/052.jpg
#   inflating: data/train/king of spades/053.jpg
#   inflating: data/train/king of spades/054.jpg
#   inflating: data/train/king of spades/055.jpg
#   inflating: data/train/king of spades/056.jpg
#   inflating: data/train/king of spades/057.jpg
#   inflating: data/train/king of spades/058.jpg
#   inflating: data/train/king of spades/059.jpg
#   inflating: data/train/king of spades/060.jpg
#   inflating: data/train/king of spades/061.jpg
#   inflating: data/train/king of spades/062.jpg
#   inflating: data/train/king of spades/063.jpg
#   inflating: data/train/king of spades/064.jpg
#   inflating: data/train/king of spades/065.jpg
#   inflating: data/train/king of spades/066.jpg
#   inflating: data/train/king of spades/067.jpg
#   inflating: data/train/king of spades/068.jpg
#   inflating: data/train/king of spades/069.jpg
#   inflating: data/train/king of spades/070.jpg
#   inflating: data/train/king of spades/071.jpg
#   inflating: data/train/king of spades/072.jpg
#   inflating: data/train/king of spades/073.jpg
#   inflating: data/train/king of spades/074.jpg
#   inflating: data/train/king of spades/075.jpg
#   inflating: data/train/king of spades/076.jpg
#   inflating: data/train/king of spades/077.jpg
#   inflating: data/train/king of spades/078.jpg
#   inflating: data/train/king of spades/079.jpg
#   inflating: data/train/king of spades/080.jpg
#   inflating: data/train/king of spades/081.jpg
#   inflating: data/train/king of spades/082.jpg
#   inflating: data/train/king of spades/083.jpg
#   inflating: data/train/king of spades/084.jpg
#   inflating: data/train/king of spades/085.jpg
#   inflating: data/train/king of spades/086.jpg
#   inflating: data/train/king of spades/087.jpg
#   inflating: data/train/king of spades/088.jpg
#   inflating: data/train/king of spades/089.jpg
#   inflating: data/train/king of spades/090.jpg
#   inflating: data/train/king of spades/091.jpg
#   inflating: data/train/king of spades/092.jpg
#   inflating: data/train/king of spades/093.jpg
#   inflating: data/train/king of spades/094.jpg
#   inflating: data/train/king of spades/095.jpg
#   inflating: data/train/king of spades/096.jpg
#   inflating: data/train/king of spades/097.jpg
#   inflating: data/train/king of spades/098.jpg
#   inflating: data/train/king of spades/099.jpg
#   inflating: data/train/king of spades/100.jpg
#   inflating: data/train/king of spades/101.jpg
#   inflating: data/train/king of spades/102.jpg
#   inflating: data/train/king of spades/103.jpg
#   inflating: data/train/king of spades/104.jpg
#   inflating: data/train/king of spades/105.jpg
#   inflating: data/train/king of spades/106.jpg
#   inflating: data/train/king of spades/107.jpg
#   inflating: data/train/king of spades/108.jpg
#   inflating: data/train/king of spades/109.jpg
#   inflating: data/train/king of spades/110.jpg
#   inflating: data/train/king of spades/111.jpg
#   inflating: data/train/king of spades/112.jpg
#   inflating: data/train/king of spades/113.jpg
#   inflating: data/train/king of spades/114.jpg
#   inflating: data/train/king of spades/115.jpg
#   inflating: data/train/king of spades/116.jpg
#   inflating: data/train/king of spades/117.jpg
#   inflating: data/train/king of spades/118.jpg
#   inflating: data/train/king of spades/119.jpg
#   inflating: data/train/king of spades/120.jpg
#   inflating: data/train/king of spades/121.jpg
#   inflating: data/train/king of spades/122.jpg
#   inflating: data/train/king of spades/123.jpg
#   inflating: data/train/king of spades/124.jpg
#   inflating: data/train/king of spades/125.jpg
#   inflating: data/train/king of spades/126.jpg
#   inflating: data/train/king of spades/127.jpg
#   inflating: data/train/king of spades/128.jpg
#   inflating: data/train/king of spades/129.jpg
#   inflating: data/train/king of spades/130.jpg
#   inflating: data/train/king of spades/131.jpg
#   inflating: data/train/king of spades/132.jpg
#   inflating: data/train/king of spades/133.jpg
#   inflating: data/train/king of spades/134.jpg
#   inflating: data/train/king of spades/135.jpg
#   inflating: data/train/king of spades/136.jpg
#   inflating: data/train/king of spades/137.jpg
#   inflating: data/train/king of spades/138.jpg
#   inflating: data/train/king of spades/139.jpg
#   inflating: data/train/king of spades/140.jpg
#   inflating: data/train/king of spades/141.jpg
#   inflating: data/train/king of spades/142.jpg
#   inflating: data/train/king of spades/143.jpg
#   inflating: data/train/king of spades/144.jpg
#   inflating: data/train/king of spades/145.jpg
#   inflating: data/train/king of spades/146.jpg
#   inflating: data/train/king of spades/147.jpg
#   inflating: data/train/king of spades/148.jpg
#   inflating: data/train/king of spades/149.jpg
#   inflating: data/train/king of spades/150.jpg
#   inflating: data/train/king of spades/151.jpg
#   inflating: data/train/nine of clubs/001.jpg
#   inflating: data/train/nine of clubs/002.jpg
#   inflating: data/train/nine of clubs/003.jpg
#   inflating: data/train/nine of clubs/004.jpg
#   inflating: data/train/nine of clubs/005.jpg
#   inflating: data/train/nine of clubs/006.jpg
#   inflating: data/train/nine of clubs/007.jpg
#   inflating: data/train/nine of clubs/008.jpg
#   inflating: data/train/nine of clubs/009.jpg
#   inflating: data/train/nine of clubs/010.jpg
#   inflating: data/train/nine of clubs/011.jpg
#   inflating: data/train/nine of clubs/012.jpg
#   inflating: data/train/nine of clubs/013.jpg
#   inflating: data/train/nine of clubs/014.jpg
#   inflating: data/train/nine of clubs/015.jpg
#   inflating: data/train/nine of clubs/016.jpg
#   inflating: data/train/nine of clubs/017.jpg
#   inflating: data/train/nine of clubs/018.jpg
#   inflating: data/train/nine of clubs/019.jpg
#   inflating: data/train/nine of clubs/020.jpg
#   inflating: data/train/nine of clubs/021.jpg
#   inflating: data/train/nine of clubs/022.jpg
#   inflating: data/train/nine of clubs/023.jpg
#   inflating: data/train/nine of clubs/024.jpg
#   inflating: data/train/nine of clubs/025.jpg
#   inflating: data/train/nine of clubs/026.jpg
#   inflating: data/train/nine of clubs/027.jpg
#   inflating: data/train/nine of clubs/028.jpg
#   inflating: data/train/nine of clubs/029.jpg
#   inflating: data/train/nine of clubs/030.jpg
#   inflating: data/train/nine of clubs/031.jpg
#   inflating: data/train/nine of clubs/032.jpg
#   inflating: data/train/nine of clubs/033.jpg
#   inflating: data/train/nine of clubs/034.jpg
#   inflating: data/train/nine of clubs/035.jpg
#   inflating: data/train/nine of clubs/036.jpg
#   inflating: data/train/nine of clubs/037.jpg
#   inflating: data/train/nine of clubs/038.jpg
#   inflating: data/train/nine of clubs/039.jpg
#   inflating: data/train/nine of clubs/040.jpg
#   inflating: data/train/nine of clubs/041.jpg
#   inflating: data/train/nine of clubs/042.jpg
#   inflating: data/train/nine of clubs/043.jpg
#   inflating: data/train/nine of clubs/044.jpg
#   inflating: data/train/nine of clubs/045.jpg
#   inflating: data/train/nine of clubs/046.jpg
#   inflating: data/train/nine of clubs/047.jpg
#   inflating: data/train/nine of clubs/048.jpg
#   inflating: data/train/nine of clubs/049.jpg
#   inflating: data/train/nine of clubs/050.jpg
#   inflating: data/train/nine of clubs/051.jpg
#   inflating: data/train/nine of clubs/052.jpg
#   inflating: data/train/nine of clubs/053.jpg
#   inflating: data/train/nine of clubs/054.jpg
#   inflating: data/train/nine of clubs/055.jpg
#   inflating: data/train/nine of clubs/056.jpg
#   inflating: data/train/nine of clubs/057.jpg
#   inflating: data/train/nine of clubs/058.jpg
#   inflating: data/train/nine of clubs/059.jpg
#   inflating: data/train/nine of clubs/060.jpg
#   inflating: data/train/nine of clubs/061.jpg
#   inflating: data/train/nine of clubs/062.jpg
#   inflating: data/train/nine of clubs/063.jpg
#   inflating: data/train/nine of clubs/064.jpg
#   inflating: data/train/nine of clubs/065.jpg
#   inflating: data/train/nine of clubs/066.jpg
#   inflating: data/train/nine of clubs/067.jpg
#   inflating: data/train/nine of clubs/068.jpg
#   inflating: data/train/nine of clubs/069.jpg
#   inflating: data/train/nine of clubs/070.jpg
#   inflating: data/train/nine of clubs/071.jpg
#   inflating: data/train/nine of clubs/072.jpg
#   inflating: data/train/nine of clubs/073.jpg
#   inflating: data/train/nine of clubs/074.jpg
#   inflating: data/train/nine of clubs/075.jpg
#   inflating: data/train/nine of clubs/076.jpg
#   inflating: data/train/nine of clubs/077.jpg
#   inflating: data/train/nine of clubs/078.jpg
#   inflating: data/train/nine of clubs/079.jpg
#   inflating: data/train/nine of clubs/080.jpg
#   inflating: data/train/nine of clubs/081.jpg
#   inflating: data/train/nine of clubs/082.jpg
#   inflating: data/train/nine of clubs/083.jpg
#   inflating: data/train/nine of clubs/084.jpg
#   inflating: data/train/nine of clubs/085.jpg
#   inflating: data/train/nine of clubs/086.jpg
#   inflating: data/train/nine of clubs/087.jpg
#   inflating: data/train/nine of clubs/088.jpg
#   inflating: data/train/nine of clubs/089.jpg
#   inflating: data/train/nine of clubs/090.jpg
#   inflating: data/train/nine of clubs/091.jpg
#   inflating: data/train/nine of clubs/092.jpg
#   inflating: data/train/nine of clubs/093.jpg
#   inflating: data/train/nine of clubs/094.jpg
#   inflating: data/train/nine of clubs/095.jpg
#   inflating: data/train/nine of clubs/096.jpg
#   inflating: data/train/nine of clubs/097.jpg
#   inflating: data/train/nine of clubs/098.jpg
#   inflating: data/train/nine of clubs/099.jpg
#   inflating: data/train/nine of clubs/100.jpg
#   inflating: data/train/nine of clubs/101.jpg
#   inflating: data/train/nine of clubs/102.jpg
#   inflating: data/train/nine of clubs/103.jpg
#   inflating: data/train/nine of clubs/104.jpg
#   inflating: data/train/nine of clubs/105.jpg
#   inflating: data/train/nine of clubs/106.jpg
#   inflating: data/train/nine of clubs/107.jpg
#   inflating: data/train/nine of clubs/108.jpg
#   inflating: data/train/nine of clubs/109.jpg
#   inflating: data/train/nine of clubs/110.jpg
#   inflating: data/train/nine of clubs/111.jpg
#   inflating: data/train/nine of clubs/112.jpg
#   inflating: data/train/nine of clubs/113.jpg
#   inflating: data/train/nine of clubs/114.jpg
#   inflating: data/train/nine of clubs/115.jpg
#   inflating: data/train/nine of clubs/116.jpg
#   inflating: data/train/nine of clubs/117.jpg
#   inflating: data/train/nine of clubs/118.jpg
#   inflating: data/train/nine of clubs/119.jpg
#   inflating: data/train/nine of clubs/120.jpg
#   inflating: data/train/nine of clubs/121.jpg
#   inflating: data/train/nine of clubs/122.jpg
#   inflating: data/train/nine of clubs/123.jpg
#   inflating: data/train/nine of clubs/124.jpg
#   inflating: data/train/nine of diamonds/001.jpg
#   inflating: data/train/nine of diamonds/002.jpg
#   inflating: data/train/nine of diamonds/003.jpg
#   inflating: data/train/nine of diamonds/004.jpg
#   inflating: data/train/nine of diamonds/005.jpg
#   inflating: data/train/nine of diamonds/006.jpg
#   inflating: data/train/nine of diamonds/007.jpg
#   inflating: data/train/nine of diamonds/008.jpg
#   inflating: data/train/nine of diamonds/009.jpg
#   inflating: data/train/nine of diamonds/010.jpg
#   inflating: data/train/nine of diamonds/011.jpg
#   inflating: data/train/nine of diamonds/012.jpg
#   inflating: data/train/nine of diamonds/013.jpg
#   inflating: data/train/nine of diamonds/014.jpg
#   inflating: data/train/nine of diamonds/015.jpg
#   inflating: data/train/nine of diamonds/016.jpg
#   inflating: data/train/nine of diamonds/017.jpg
#   inflating: data/train/nine of diamonds/018.jpg
#   inflating: data/train/nine of diamonds/019.jpg
#   inflating: data/train/nine of diamonds/020.jpg
#   inflating: data/train/nine of diamonds/021.jpg
#   inflating: data/train/nine of diamonds/022.jpg
#   inflating: data/train/nine of diamonds/023.jpg
#   inflating: data/train/nine of diamonds/024.jpg
#   inflating: data/train/nine of diamonds/025.jpg
#   inflating: data/train/nine of diamonds/026.jpg
#   inflating: data/train/nine of diamonds/027.jpg
#   inflating: data/train/nine of diamonds/028.jpg
#   inflating: data/train/nine of diamonds/029.jpg
#   inflating: data/train/nine of diamonds/030.jpg
#   inflating: data/train/nine of diamonds/031.jpg
#   inflating: data/train/nine of diamonds/032.jpg
#   inflating: data/train/nine of diamonds/033.jpg
#   inflating: data/train/nine of diamonds/034.jpg
#   inflating: data/train/nine of diamonds/035.jpg
#   inflating: data/train/nine of diamonds/036.jpg
#   inflating: data/train/nine of diamonds/037.jpg
#   inflating: data/train/nine of diamonds/038.jpg
#   inflating: data/train/nine of diamonds/039.jpg
#   inflating: data/train/nine of diamonds/040.jpg
#   inflating: data/train/nine of diamonds/041.jpg
#   inflating: data/train/nine of diamonds/042.jpg
#   inflating: data/train/nine of diamonds/043.jpg
#   inflating: data/train/nine of diamonds/044.jpg
#   inflating: data/train/nine of diamonds/045.jpg
#   inflating: data/train/nine of diamonds/046.jpg
#   inflating: data/train/nine of diamonds/047.jpg
#   inflating: data/train/nine of diamonds/048.jpg
#   inflating: data/train/nine of diamonds/049.jpg
#   inflating: data/train/nine of diamonds/050.jpg
#   inflating: data/train/nine of diamonds/051.jpg
#   inflating: data/train/nine of diamonds/052.jpg
#   inflating: data/train/nine of diamonds/053.jpg
#   inflating: data/train/nine of diamonds/054.jpg
#   inflating: data/train/nine of diamonds/055.jpg
#   inflating: data/train/nine of diamonds/056.jpg
#   inflating: data/train/nine of diamonds/057.jpg
#   inflating: data/train/nine of diamonds/058.jpg
#   inflating: data/train/nine of diamonds/059.jpg
#   inflating: data/train/nine of diamonds/060.jpg
#   inflating: data/train/nine of diamonds/061.jpg
#   inflating: data/train/nine of diamonds/062.jpg
#   inflating: data/train/nine of diamonds/063.jpg
#   inflating: data/train/nine of diamonds/064.jpg
#   inflating: data/train/nine of diamonds/065.jpg
#   inflating: data/train/nine of diamonds/066.jpg
#   inflating: data/train/nine of diamonds/067.jpg
#   inflating: data/train/nine of diamonds/068.jpg
#   inflating: data/train/nine of diamonds/069.jpg
#   inflating: data/train/nine of diamonds/070.jpg
#   inflating: data/train/nine of diamonds/071.jpg
#   inflating: data/train/nine of diamonds/072.jpg
#   inflating: data/train/nine of diamonds/073.jpg
#   inflating: data/train/nine of diamonds/074.jpg
#   inflating: data/train/nine of diamonds/075.jpg
#   inflating: data/train/nine of diamonds/076.jpg
#   inflating: data/train/nine of diamonds/077.jpg
#   inflating: data/train/nine of diamonds/078.jpg
#   inflating: data/train/nine of diamonds/079.jpg
#   inflating: data/train/nine of diamonds/080.jpg
#   inflating: data/train/nine of diamonds/081.jpg
#   inflating: data/train/nine of diamonds/082.jpg
#   inflating: data/train/nine of diamonds/083.jpg
#   inflating: data/train/nine of diamonds/084.jpg
#   inflating: data/train/nine of diamonds/085.jpg
#   inflating: data/train/nine of diamonds/086.jpg
#   inflating: data/train/nine of diamonds/087.jpg
#   inflating: data/train/nine of diamonds/088.jpg
#   inflating: data/train/nine of diamonds/089.jpg
#   inflating: data/train/nine of diamonds/090.jpg
#   inflating: data/train/nine of diamonds/091.jpg
#   inflating: data/train/nine of diamonds/092.jpg
#   inflating: data/train/nine of diamonds/093.jpg
#   inflating: data/train/nine of diamonds/094.jpg
#   inflating: data/train/nine of diamonds/095.jpg
#   inflating: data/train/nine of diamonds/096.jpg
#   inflating: data/train/nine of diamonds/097.jpg
#   inflating: data/train/nine of diamonds/098.jpg
#   inflating: data/train/nine of diamonds/099.jpg
#   inflating: data/train/nine of diamonds/100.jpg
#   inflating: data/train/nine of diamonds/101.jpg
#   inflating: data/train/nine of diamonds/102.jpg
#   inflating: data/train/nine of diamonds/103.jpg
# ...
#   inflating: data/train/two of spades/083.jpg
#   inflating: data/train/two of spades/084.jpg
#   inflating: data/train/two of spades/085.jpg
#   inflating: data/train/two of spades/086.jpg
#   inflating: data/train/two of spades/087.jpg
#   inflating: data/train/two of spades/088.jpg
#   inflating: data/train/two of spades/089.jpg
#   inflating: data/train/two of spades/090.jpg
#   inflating: data/train/two of spades/091.jpg
#   inflating: data/train/two of spades/092.jpg
#   inflating: data/train/two of spades/093.jpg
#   inflating: data/train/two of spades/094.jpg
#   inflating: data/train/two of spades/095.jpg
#   inflating: data/train/two of spades/096.jpg
#   inflating: data/train/two of spades/097.jpg
#   inflating: data/train/two of spades/098.jpg
#   inflating: data/train/two of spades/099.jpg
#   inflating: data/train/two of spades/100.jpg
#   inflating: data/train/two of spades/101.jpg
#   inflating: data/train/two of spades/102.jpg
#   inflating: data/train/two of spades/103.jpg
#   inflating: data/train/two of spades/104.jpg
#   inflating: data/train/two of spades/105.jpg
#   inflating: data/train/two of spades/106.jpg
#   inflating: data/train/two of spades/107.jpg
#   inflating: data/train/two of spades/108.jpg
#   inflating: data/train/two of spades/109.jpg
#   inflating: data/train/two of spades/110.jpg
#   inflating: data/train/two of spades/111.jpg
#   inflating: data/train/two of spades/112.jpg
#   inflating: data/train/two of spades/113.jpg
#   inflating: data/train/two of spades/114.jpg
#   inflating: data/train/two of spades/115.jpg
#   inflating: data/train/two of spades/116.jpg
#   inflating: data/train/two of spades/117.jpg
#   inflating: data/train/two of spades/118.jpg
#   inflating: data/train/two of spades/119.jpg
#   inflating: data/train/two of spades/120.jpg
#   inflating: data/train/two of spades/121.jpg
#   inflating: data/train/two of spades/122.jpg
#   inflating: data/train/two of spades/123.jpg
#   inflating: data/train/two of spades/124.jpg
#   inflating: data/train/two of spades/125.jpg
#   inflating: data/train/two of spades/126.jpg
#   inflating: data/train/two of spades/127.jpg
#   inflating: data/train/two of spades/128.jpg
#   inflating: data/train/two of spades/129.jpg
#   inflating: data/train/two of spades/130.jpg
#   inflating: data/train/two of spades/131.jpg
#   inflating: data/train/two of spades/132.jpg
#   inflating: data/train/two of spades/133.jpg
#   inflating: data/train/two of spades/134.jpg
#   inflating: data/train/two of spades/135.jpg
#   inflating: data/train/two of spades/136.jpg
#   inflating: data/train/two of spades/137.jpg
#   inflating: data/train/two of spades/138.jpg
#   inflating: data/train/two of spades/139.jpg
#   inflating: data/train/two of spades/140.jpg
#   inflating: data/train/two of spades/141.jpg
#   inflating: data/train/two of spades/142.jpg
#   inflating: data/train/two of spades/143.jpg
#   inflating: data/train/two of spades/144.jpg
#   inflating: data/train/two of spades/145.jpg
#   inflating: data/train/two of spades/146.jpg
#   inflating: data/train/two of spades/147.jpg
#   inflating: data/train/two of spades/148.jpg
#   inflating: data/train/two of spades/149.jpg
#   inflating: data/train/two of spades/150.jpg
#   inflating: data/train/two of spades/151.jpg
#   inflating: data/train/two of spades/152.jpg
#   inflating: data/train/two of spades/153.jpg
#   inflating: data/train/two of spades/154.jpg
#   inflating: data/train/two of spades/155.jpg
#   inflating: data/valid/ace of clubs/1.jpg
#   inflating: data/valid/ace of clubs/2.jpg
#   inflating: data/valid/ace of clubs/3.jpg
#   inflating: data/valid/ace of clubs/4.jpg
#   inflating: data/valid/ace of clubs/5.jpg
#   inflating: data/valid/ace of diamonds/1.jpg
#   inflating: data/valid/ace of diamonds/2.jpg
#   inflating: data/valid/ace of diamonds/3.jpg
#   inflating: data/valid/ace of diamonds/4.jpg
#   inflating: data/valid/ace of diamonds/5.jpg
#   inflating: data/valid/ace of hearts/1.jpg
#   inflating: data/valid/ace of hearts/2.jpg
#   inflating: data/valid/ace of hearts/3.jpg
#   inflating: data/valid/ace of hearts/4.jpg
#   inflating: data/valid/ace of hearts/5.jpg
#   inflating: data/valid/ace of spades/1.jpg
#   inflating: data/valid/ace of spades/2.jpg
#   inflating: data/valid/ace of spades/3.jpg
#   inflating: data/valid/ace of spades/4.jpg
#   inflating: data/valid/ace of spades/5.jpg
#   inflating: data/valid/eight of clubs/1.jpg
#   inflating: data/valid/eight of clubs/2.jpg
#   inflating: data/valid/eight of clubs/3.jpg
#   inflating: data/valid/eight of clubs/4.jpg
#   inflating: data/valid/eight of clubs/5.jpg
#   inflating: data/valid/eight of diamonds/1.jpg
#   inflating: data/valid/eight of diamonds/2.jpg
#   inflating: data/valid/eight of diamonds/3.jpg
#   inflating: data/valid/eight of diamonds/4.jpg
#   inflating: data/valid/eight of diamonds/5.jpg
#   inflating: data/valid/eight of hearts/1.jpg
#   inflating: data/valid/eight of hearts/2.jpg
#   inflating: data/valid/eight of hearts/3.jpg
#   inflating: data/valid/eight of hearts/4.jpg
#   inflating: data/valid/eight of hearts/5.jpg
#   inflating: data/valid/eight of spades/1.jpg
#   inflating: data/valid/eight of spades/2.jpg
#   inflating: data/valid/eight of spades/3.jpg
#   inflating: data/valid/eight of spades/4.jpg
#   inflating: data/valid/eight of spades/5.jpg
#   inflating: data/valid/five of clubs/1.jpg
#   inflating: data/valid/five of clubs/2.jpg
#   inflating: data/valid/five of clubs/3.jpg
#   inflating: data/valid/five of clubs/4.jpg
#   inflating: data/valid/five of clubs/5.jpg
#   inflating: data/valid/five of diamonds/1.jpg
#   inflating: data/valid/five of diamonds/2.jpg
#   inflating: data/valid/five of diamonds/3.jpg
#   inflating: data/valid/five of diamonds/4.jpg
#   inflating: data/valid/five of diamonds/5.jpg
#   inflating: data/valid/five of hearts/1.jpg
#   inflating: data/valid/five of hearts/2.jpg
#   inflating: data/valid/five of hearts/3.jpg
#   inflating: data/valid/five of hearts/4.jpg
#   inflating: data/valid/five of hearts/5.jpg
#   inflating: data/valid/five of spades/1.jpg
#   inflating: data/valid/five of spades/2.jpg
#   inflating: data/valid/five of spades/3.jpg
#   inflating: data/valid/five of spades/4.jpg
#   inflating: data/valid/five of spades/5.jpg
#   inflating: data/valid/four of clubs/1.jpg
#   inflating: data/valid/four of clubs/2.jpg
#   inflating: data/valid/four of clubs/3.jpg
#   inflating: data/valid/four of clubs/4.jpg
#   inflating: data/valid/four of clubs/5.jpg
#   inflating: data/valid/four of diamonds/1.jpg
#   inflating: data/valid/four of diamonds/2.jpg
#   inflating: data/valid/four of diamonds/3.jpg
#   inflating: data/valid/four of diamonds/4.jpg
#   inflating: data/valid/four of diamonds/5.jpg
#   inflating: data/valid/four of hearts/1.jpg
#   inflating: data/valid/four of hearts/2.jpg
#   inflating: data/valid/four of hearts/3.jpg
#   inflating: data/valid/four of hearts/4.jpg
#   inflating: data/valid/four of hearts/5.jpg
#   inflating: data/valid/four of spades/1.jpg
#   inflating: data/valid/four of spades/2.jpg
#   inflating: data/valid/four of spades/3.jpg
#   inflating: data/valid/four of spades/4.jpg
#   inflating: data/valid/four of spades/5.jpg
#   inflating: data/valid/jack of clubs/1.jpg
#   inflating: data/valid/jack of clubs/2.jpg
#   inflating: data/valid/jack of clubs/3.jpg
#   inflating: data/valid/jack of clubs/4.jpg
#   inflating: data/valid/jack of clubs/5.jpg
#   inflating: data/valid/jack of diamonds/1.jpg
#   inflating: data/valid/jack of diamonds/2.jpg
#   inflating: data/valid/jack of diamonds/3.jpg
#   inflating: data/valid/jack of diamonds/4.jpg
#   inflating: data/valid/jack of diamonds/5.jpg
#   inflating: data/valid/jack of hearts/1.jpg
#   inflating: data/valid/jack of hearts/2.jpg
#   inflating: data/valid/jack of hearts/3.jpg
#   inflating: data/valid/jack of hearts/4.jpg
#   inflating: data/valid/jack of hearts/5.jpg
#   inflating: data/valid/jack of spades/1.jpg
#   inflating: data/valid/jack of spades/2.jpg
#   inflating: data/valid/jack of spades/3.jpg
#   inflating: data/valid/jack of spades/4.jpg
#   inflating: data/valid/jack of spades/5.jpg
#   inflating: data/valid/joker/1.jpg
#   inflating: data/valid/joker/2.jpg
#   inflating: data/valid/joker/3.jpg
#   inflating: data/valid/joker/4.jpg
#   inflating: data/valid/joker/5.jpg
#   inflating: data/valid/king of clubs/1.jpg
#   inflating: data/valid/king of clubs/2.jpg
#   inflating: data/valid/king of clubs/3.jpg
#   inflating: data/valid/king of clubs/4.jpg
#   inflating: data/valid/king of clubs/5.jpg
#   inflating: data/valid/king of diamonds/1.jpg
#   inflating: data/valid/king of diamonds/2.jpg
#   inflating: data/valid/king of diamonds/3.jpg
#   inflating: data/valid/king of diamonds/4.jpg
#   inflating: data/valid/king of diamonds/5.jpg
#   inflating: data/valid/king of hearts/1.jpg
#   inflating: data/valid/king of hearts/2.jpg
#   inflating: data/valid/king of hearts/3.jpg
#   inflating: data/valid/king of hearts/4.jpg
#   inflating: data/valid/king of hearts/5.jpg
#   inflating: data/valid/king of spades/1.jpg
#   inflating: data/valid/king of spades/2.jpg
#   inflating: data/valid/king of spades/3.jpg
#   inflating: data/valid/king of spades/4.jpg
#   inflating: data/valid/king of spades/5.jpg
#   inflating: data/valid/nine of clubs/1.jpg
#   inflating: data/valid/nine of clubs/2.jpg
#   inflating: data/valid/nine of clubs/3.jpg
#   inflating: data/valid/nine of clubs/4.jpg
#   inflating: data/valid/nine of clubs/5.jpg
#   inflating: data/valid/nine of diamonds/1.jpg
#   inflating: data/valid/nine of diamonds/2.jpg
#   inflating: data/valid/nine of diamonds/3.jpg
#   inflating: data/valid/nine of diamonds/4.jpg
#   inflating: data/valid/nine of diamonds/5.jpg
#   inflating: data/valid/nine of hearts/1.jpg
#   inflating: data/valid/nine of hearts/2.jpg
#   inflating: data/valid/nine of hearts/3.jpg
#   inflating: data/valid/nine of hearts/4.jpg
#   inflating: data/valid/nine of hearts/5.jpg
#   inflating: data/valid/nine of spades/1.jpg
#   inflating: data/valid/nine of spades/2.jpg
#   inflating: data/valid/nine of spades/3.jpg
#   inflating: data/valid/nine of spades/4.jpg
#   inflating: data/valid/nine of spades/5.jpg
#   inflating: data/valid/queen of clubs/1.jpg
#   inflating: data/valid/queen of clubs/2.jpg
#   inflating: data/valid/queen of clubs/3.jpg
#   inflating: data/valid/queen of clubs/4.jpg
#   inflating: data/valid/queen of clubs/5.jpg
#   inflating: data/valid/queen of diamonds/1.jpg
#   inflating: data/valid/queen of diamonds/2.jpg
#   inflating: data/valid/queen of diamonds/3.jpg
#   inflating: data/valid/queen of diamonds/4.jpg
#   inflating: data/valid/queen of diamonds/5.jpg
#   inflating: data/valid/queen of hearts/1.jpg
#   inflating: data/valid/queen of hearts/2.jpg
#   inflating: data/valid/queen of hearts/3.jpg
#   inflating: data/valid/queen of hearts/4.jpg
#   inflating: data/valid/queen of hearts/5.jpg
#   inflating: data/valid/queen of spades/1.jpg
#   inflating: data/valid/queen of spades/2.jpg
#   inflating: data/valid/queen of spades/3.jpg
#   inflating: data/valid/queen of spades/4.jpg
#   inflating: data/valid/queen of spades/5.jpg
#   inflating: data/valid/seven of clubs/1.jpg
#   inflating: data/valid/seven of clubs/2.jpg
#   inflating: data/valid/seven of clubs/3.jpg
#   inflating: data/valid/seven of clubs/4.jpg
#   inflating: data/valid/seven of clubs/5.jpg
#   inflating: data/valid/seven of diamonds/1.jpg
#   inflating: data/valid/seven of diamonds/2.jpg
#   inflating: data/valid/seven of diamonds/3.jpg
#   inflating: data/valid/seven of diamonds/4.jpg
#   inflating: data/valid/seven of diamonds/5.jpg
#   inflating: data/valid/seven of hearts/1.jpg
#   inflating: data/valid/seven of hearts/2.jpg
#   inflating: data/valid/seven of hearts/3.jpg
#   inflating: data/valid/seven of hearts/4.jpg
#   inflating: data/valid/seven of hearts/5.jpg
#   inflating: data/valid/seven of spades/1.jpg
#   inflating: data/valid/seven of spades/2.jpg
#   inflating: data/valid/seven of spades/3.jpg
#   inflating: data/valid/seven of spades/4.jpg
#   inflating: data/valid/seven of spades/5.jpg
#   inflating: data/valid/six of clubs/1.jpg
#   inflating: data/valid/six of clubs/2.jpg
#   inflating: data/valid/six of clubs/3.jpg
#   inflating: data/valid/six of clubs/4.jpg
#   inflating: data/valid/six of clubs/5.jpg
#   inflating: data/valid/six of diamonds/1.jpg
#   inflating: data/valid/six of diamonds/2.jpg
#   inflating: data/valid/six of diamonds/3.jpg
#   inflating: data/valid/six of diamonds/4.jpg
#   inflating: data/valid/six of diamonds/5.jpg
#   inflating: data/valid/six of hearts/1.jpg
#   inflating: data/valid/six of hearts/2.jpg
#   inflating: data/valid/six of hearts/3.jpg
#   inflating: data/valid/six of hearts/4.jpg
#   inflating: data/valid/six of hearts/5.jpg
#   inflating: data/valid/six of spades/1.jpg
#   inflating: data/valid/six of spades/2.jpg
#   inflating: data/valid/six of spades/3.jpg
#   inflating: data/valid/six of spades/4.jpg
#   inflating: data/valid/six of spades/5.jpg
#   inflating: data/valid/ten of clubs/1.jpg
#   inflating: data/valid/ten of clubs/2.jpg
#   inflating: data/valid/ten of clubs/3.jpg
#   inflating: data/valid/ten of clubs/4.jpg
#   inflating: data/valid/ten of clubs/5.jpg
#   inflating: data/valid/ten of diamonds/1.jpg
#   inflating: data/valid/ten of diamonds/2.jpg
#   inflating: data/valid/ten of diamonds/3.jpg
#   inflating: data/valid/ten of diamonds/4.jpg
#   inflating: data/valid/ten of diamonds/5.jpg
#   inflating: data/valid/ten of hearts/1.jpg
#   inflating: data/valid/ten of hearts/2.jpg
#   inflating: data/valid/ten of hearts/3.jpg
#   inflating: data/valid/ten of hearts/4.jpg
#   inflating: data/valid/ten of hearts/5.jpg
#   inflating: data/valid/ten of spades/1.jpg
#   inflating: data/valid/ten of spades/2.jpg
#   inflating: data/valid/ten of spades/3.jpg
#   inflating: data/valid/ten of spades/4.jpg
#   inflating: data/valid/ten of spades/5.jpg
#   inflating: data/valid/three of clubs/1.jpg
#   inflating: data/valid/three of clubs/2.jpg
#   inflating: data/valid/three of clubs/3.jpg
#   inflating: data/valid/three of clubs/4.jpg
#   inflating: data/valid/three of clubs/5.jpg
#   inflating: data/valid/three of diamonds/1.jpg
#   inflating: data/valid/three of diamonds/2.jpg
#   inflating: data/valid/three of diamonds/3.jpg
#   inflating: data/valid/three of diamonds/4.jpg
#   inflating: data/valid/three of diamonds/5.jpg
#   inflating: data/valid/three of hearts/1.jpg
#   inflating: data/valid/three of hearts/2.jpg
#   inflating: data/valid/three of hearts/3.jpg
#   inflating: data/valid/three of hearts/4.jpg
#   inflating: data/valid/three of hearts/5.jpg
#   inflating: data/valid/three of spades/1.jpg
#   inflating: data/valid/three of spades/2.jpg
#   inflating: data/valid/three of spades/3.jpg
#   inflating: data/valid/three of spades/4.jpg
#   inflating: data/valid/three of spades/5.jpg
#   inflating: data/valid/two of clubs/1.jpg
#   inflating: data/valid/two of clubs/2.jpg
#   inflating: data/valid/two of clubs/3.jpg
#   inflating: data/valid/two of clubs/4.jpg
#   inflating: data/valid/two of clubs/5.jpg
#   inflating: data/valid/two of diamonds/1.jpg
#   inflating: data/valid/two of diamonds/2.jpg
#   inflating: data/valid/two of diamonds/3.jpg
#   inflating: data/valid/two of diamonds/4.jpg
#   inflating: data/valid/two of diamonds/5.jpg
#   inflating: data/valid/two of hearts/1.jpg
#   inflating: data/valid/two of hearts/2.jpg
#   inflating: data/valid/two of hearts/3.jpg
#   inflating: data/valid/two of hearts/4.jpg
#   inflating: data/valid/two of hearts/5.jpg
#   inflating: data/valid/two of spades/1.jpg
#   inflating: data/valid/two of spades/2.jpg
#   inflating: data/valid/two of spades/3.jpg
#   inflating: data/valid/two of spades/4.jpg
#   inflating: data/valid/two of spades/5.jpg

# %% [markdown]
# ## CNN Architecture

# %%
class CNNClassifier(nn.Module):
    def __init__(self, in_channel, output_dim):
        super(CNNClassifier, self).__init__()

        self.model = nn.Sequential(
            nn.Conv2d(in_channel, 64, 3),
            nn.ReLU(),
            nn.BatchNorm2d(64),

            nn.Conv2d(64, 64, 3, 2),
            nn.ReLU(),
            nn.BatchNorm2d(64),

            nn.Conv2d(64, 128, 3),
            nn.ReLU(),
            nn.BatchNorm2d(128),

            nn.Conv2d(128, 128, 3, 2),
            nn.ReLU(),
            nn.BatchNorm2d(128),

            nn.Conv2d(128, 256, 3),
            nn.ReLU(),
            nn.BatchNorm2d(256),

            nn.Conv2d(256, 256, 3, 2),
            nn.ReLU(),
            nn.BatchNorm2d(256),

            nn.Conv2d(256, 512, 3),
            nn.ReLU(),
            nn.BatchNorm2d(512),

            nn.Conv2d(512, 512, 3, 2),
            nn.ReLU(),
            nn.BatchNorm2d(512),

            nn.Flatten(),

            nn.Linear(73728, 120),
            nn.ReLU(),

            nn.Linear(120, 84),
            nn.ReLU(),

            nn.Linear(84, output_dim),
            nn.Softmax(dim=1)
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## Functions

# %%
def print_txt(text: str, txt_file):
    print(text)
    txt_file.write(text)
    txt_file.write("\n")

# %%
def get_model_information(model, txt_file):
  # Print the model architecture
  print_txt(str(model), txt_file)

  # Calculate the number of parameters
  total_params = sum(p.numel() for p in model.parameters())
  trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

  print_txt(f"Total parameters: {total_params}", txt_file)
  print_txt(f"Trainable parameters: {trainable_params}", txt_file)

# %%
# Transform a one hot vector into an integer (index of the maximum value)
def vec_to_int(y_true, y_predicted):
    # Vérifiez si y_true est déjà un vecteur d'indices
    if len(y_true.shape) == 1:
        y_true_int = y_true
    else:
        y_true_int = np.argmax(y_true, axis=1)

    # Vérifiez si y_predicted est déjà un vecteur d'indices
    if len(y_predicted.shape) == 1:
        y_predicted_int = y_predicted
    else:
        y_predicted_int = np.argmax(y_predicted, axis=1)

    return y_true_int, y_predicted_int

# %%
# This function can be used for the training and validation stage
def model_performances(y_true, y_predicted, loss, my_score_df):

    # Initialize a list
    scores = []

    # Get the index of the maximum value in the vectors "y_true" and "y_predicted"
    y_int_true, y_int_predicted = vec_to_int(y_true, y_predicted)

    # Compute scores and add them to the list scores
    scores.extend([loss])
    scores.extend([accuracy_score(y_int_true, y_int_predicted)])
    scores.extend([balanced_accuracy_score(y_int_true, y_int_predicted)])
    scores.extend([f1_score(y_int_true, y_int_predicted, average="micro")])
    scores.extend([cohen_kappa_score(y_int_true, y_int_predicted)])
    scores.extend([top_k_accuracy_score(y_int_true, y_predicted, k=2)])
    scores.extend([top_k_accuracy_score(y_int_true, y_predicted, k=3)])

    my_score_df.loc[len(my_score_df)] = scores

    return my_score_df

# %%
# This function is only to use on the test set
def show_compute_model_performances(y_true, y_predicted, loss, my_score_df, classes, txt_file):

    # Initialize a list
    scores = []

    # Get the index of the maximum value in the vectors "y_true" and "y_predicted"
    y_int_true, y_int_predicted = vec_to_int(y_true, y_predicted)

    # Compute scores, add them to the list scores and show them
    scores.extend([loss])

    # Accuracy
    accuracy = accuracy_score(y_int_true, y_int_predicted)
    print_txt(f"Accuracy: {accuracy}", txt_file)
    scores.extend([accuracy])

    # Balanced accuracy
    balanced_accuracy = balanced_accuracy_score(y_int_true, y_int_predicted)
    print_txt(f"Balanced Accuracy: {balanced_accuracy}", txt_file)
    scores.extend([balanced_accuracy])

    # F1-score
    f1 = f1_score(y_int_true, y_int_predicted, average="micro")
    print_txt(f"F1-score: {f1}", txt_file)
    scores.extend([f1])

    # Cohen Kappa
    kappa = cohen_kappa_score(y_int_true, y_int_predicted)
    print_txt(f"Kappa: {kappa}", txt_file)
    scores.extend([kappa])

    # Confusion matrix
    if len(y_true.shape) > 1 and y_true.shape[1] <= 10:  # Vérifie si y_true est 2D
        print_txt(str(confusion_matrix(y_int_true, y_int_predicted)), txt_file)

    # Classification report
    print_txt(str(classification_report(y_int_true, y_int_predicted, target_names=classes)), txt_file)

    # Top 2 accuracy
    top_2 = top_k_accuracy_score(y_int_true, y_predicted, k=2)
    print_txt(f"Top 2 Accuracy: {top_2}", txt_file)
    scores.extend([top_2])

    # Top 3 accuracy
    top_3 = top_k_accuracy_score(y_int_true, y_predicted, k=3)
    print_txt(f"Top 3 Accuracy: {top_3}", txt_file)
    scores.extend([top_3])

    my_score_df.loc[len(my_score_df)] = scores

    return my_score_df

# %%
def create_score_df(training_epoch_scores, validation_epoch_scores, score_type):

    # Create a DataFrame for plotting the train "score_type"
    train_df = pd.DataFrame(columns=["Epochs", "Stage", score_type])
    # Create the vectors of values for the epochs and the stage of the training process
    epochs = np.arange(1, training_epoch_scores.shape[0] + 1, 1)
    stage = ["Train"] * training_epoch_scores.shape[0]
    # Fill the DataFrame for the train "score_type"
    train_df["Epochs"] = epochs
    train_df["Stage"] = stage
    train_df[score_type] = training_epoch_scores[score_type]

    # Create a DataFrame for plotting the validation "score_type"
    validation_df = pd.DataFrame(columns=["Epochs", "Stage", score_type])
    # Create the vector of values for the stage of the training process
    stage = ["Validation"] * training_epoch_scores.shape[0]
    # Fill the DataFrame for the validation "score_type"
    validation_df["Epochs"] = epochs
    validation_df["Stage"] = stage
    validation_df[score_type] = validation_epoch_scores[score_type]

    # Merge the two DataFrame
    score_df = pd.concat([train_df, validation_df])

    return score_df

# %%
def plot_score_graphs(training_epoch_scores, validation_epoch_scores, results_path, my_folder_name):

    # List of scores to plot
    scores_to_plot = ["Loss", "Accuracy", "Balanced Accuracy", "F1-score", "Kappa", "Top 2 Accuracy", "Top 3 Accuracy"]

    # For each score to plot in the defined list
    for score_type in scores_to_plot:

        # Create the DataFrame to be used with Plotly
        the_df = create_score_df(training_epoch_scores, validation_epoch_scores, score_type)

        # Plot the score evolution for the training and validation stages
        fig = px.line(the_df, x="Epochs", y=score_type, color="Stage")
        # Temporary path
        temp_path = os.path.join(results_path, my_folder_name)
        # Save the graph
        fig.write_html(os.path.join(temp_path, score_type + ".html"))

# %%
def compute_accuracy(labels, outputs):

    # Ajustement des dimensions si nécessaire
    if len(labels.shape) > 1:  # One-hot encoded labels
        labels = labels.argmax(dim=1)
    outputs = outputs.argmax(dim=1)

    # Calcul de l'exactitude
    accuracy = (labels == outputs).float().mean().item()
    return accuracy

# %%
def compute_model_outputs(inputs, labels, device, model, all_labels, all_outputs, loss_function):
    # Déplacer les entrées et les labels sur le bon appareil
    inputs, labels = inputs.to(device), labels.to(device)

    # Calculer les sorties du modèle
    outputs = model(inputs)

    # Si les labels sont en one-hot, convertissez-les en indices de classe
    if labels.ndimension() > 1:  # vérifier si les labels sont one-hot encodés
        labels = torch.argmax(labels, dim=1)  # convertissez en indices de classe

    # Calculer la perte
    loss = loss_function(outputs, labels)

    # Calculer la précision
    accuracy = compute_accuracy(labels, outputs)

    # Ajouter les résultats à la liste
    all_labels.extend(labels.cpu().numpy())
    all_outputs.extend(outputs.cpu().detach().numpy())

    return all_labels, all_outputs, loss, accuracy

# %% [markdown]
# ## Functions : Train, Validate, Test

# %%
def test_model(test_loader, model, loss_function, device, classes, txt_file):

    # Initialize a DataFrame where to store metrics
    test_scores = pd.DataFrame(columns=["Loss", "Accuracy", "Balanced Accuracy", "F1-score", "Kappa",
                                        "Top 2 Accuracy", "Top 3 Accuracy"])

    # Tell to your model that your are evaluating it
    model.eval()

    # Initialize a mini-batch counter
    mini_batch_counter = 0

    # Initialize the loss and accuracy
    running_loss = 0.0
    running_accuracy = 0.0

    # Initialize two variables to store the outputs of the neural network and the labels (for the whole test set)
    all_outputs = []
    all_labels = []

    # Assign the tqdm iterator to the variable "progress_testing"
    with tqdm(test_loader, unit=" mini-batch") as progress_testing:

        # For each mini-batch defined in the validation loader through the variable "progress_validation"
        for inputs, labels in progress_testing:

            progress_testing.set_description("Testing the training model")

            # Compute the outputs of the model with specific inputs
            all_labels, all_outputs, loss, accuracy = compute_model_outputs(inputs, labels, device, model,
                                                                            all_labels, all_outputs, loss_function)

            # Update the running loss
            running_loss += loss.item()
            # Update the running accuracy
            running_accuracy += accuracy

            # Display the updated loss and the accuracy
            progress_testing.set_postfix(testing_loss=running_loss / (mini_batch_counter + 1),
                                         testing_accuracy=100. * (running_accuracy / (mini_batch_counter + 1)))

            # Increment the mini-batch counter
            mini_batch_counter += 1

    # Compute the performances on the test set and store them
    test_scores = show_compute_model_performances(np.array(all_labels), np.array(all_outputs),
                                                  running_loss / mini_batch_counter, test_scores, classes, txt_file)

    return test_scores

# %%
def train_model(epoch_number, train_loader, validation_loader, model, optimizer, loss_function, device, results_path, my_folder_name):
    # Initialize a DataFrame where to store metrics
    training_epoch_scores = pd.DataFrame(columns=["Loss", "Accuracy", "Balanced Accuracy", "F1-score", "Kappa",
                                                  "Top 2 Accuracy", "Top 3 Accuracy"])
    validation_epoch_scores = pd.DataFrame(columns=["Loss", "Accuracy", "Balanced Accuracy", "F1-score", "Kappa",
                                                    "Top 2 Accuracy", "Top 3 Accuracy"])

    # Tell to your model that your are training it
    model.train()

    # For each epoch
    for epoch in range(epoch_number):

        # Initialize a mini-batch counter
        mini_batch_counter = 0

        # Initialize the loss and accuracy
        running_loss = 0.0
        running_accuracy = 0.0

        # Initialize two variables to store the outputs of the neural network and the labels (for the whole epoch)
        all_outputs = []
        all_labels = []

        # Assign the tqdm iterator to the variable "progress_epoch"
        with tqdm(train_loader, unit=" mini-batch") as progress_epoch:

            # For each mini-batch defined in the train loader through the variable "progress_epoch"
            for inputs, labels in progress_epoch:

                # Set the description of the progress bar
                progress_epoch.set_description(f"Epoch {epoch + 1}/{epoch_number}")

                # Compute the outputs of the model with specific inputs
                all_labels, all_outputs, loss, accuracy = compute_model_outputs(inputs, labels, device, model,
                                                                                all_labels, all_outputs, loss_function)

                # Update the weights and biais of the network
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                # Update the running loss
                running_loss += loss.item()
                # Update the running accuracy
                running_accuracy += accuracy

                # Display the updated loss and the accuracy
                progress_epoch.set_postfix(train_loss=running_loss / (mini_batch_counter + 1),
                                           train_accuracy=100. * (running_accuracy / (mini_batch_counter + 1)))

                # Increment the mini-batch counter
                mini_batch_counter += 1

        # Compute the performances of the training on the current epoch and store the scores
        training_epoch_scores = model_performances(np.array(all_labels), np.array(all_outputs),
                                                   running_loss / mini_batch_counter, training_epoch_scores)

        # Check performance of the model on the validation set after each training epoch
        validation_epoch_scores = validate_model(validation_loader, model, loss_function, device,
                                                 validation_epoch_scores)

    # Plot metrics
    plot_score_graphs(training_epoch_scores, validation_epoch_scores, results_path, my_folder_name)

    return model

# %%
def validate_model(validation_loader, model, loss_function, device, validation_epoch_scores):

    # Tell to your model that your are evaluating it
    model.eval()

    # Initialize a mini-batch counter
    mini_batch_counter = 0

    # Initialize the loss and accuracy
    running_loss = 0.0
    running_accuracy = 0.0

    # Initialize two variables to store the outputs of the neural network and the labels (for the whole validation set
    # at the end of the current epoch)
    all_outputs = []
    all_labels = []

    # Assign the tqdm iterator to the variable "progress_validation"
    with tqdm(validation_loader, unit=" mini-batch") as progress_validation:

        # For each mini-batch defined in the validation loader through the variable "progress_validation"
        for inputs, labels in progress_validation:

            # Set the description of the progress bar
            progress_validation.set_description("               Validation step")

            # Compute the outputs of the model with specific inputs
            all_labels, all_outputs, loss, accuracy = compute_model_outputs(inputs, labels, device, model, all_labels,
                                                                            all_outputs, loss_function)

            # Update the running loss
            running_loss += loss.item()
            # Update the running accuracy
            running_accuracy += accuracy

            # Display the updated loss and the accuracy
            progress_validation.set_postfix(validation_loss=running_loss / (mini_batch_counter + 1),
                                            validation_accuracy=100. * (running_accuracy / (mini_batch_counter + 1)))

            # Increment the mini-batch counter
            mini_batch_counter += 1

    # Compute the performances on the validation set of the current epoch and store the scores
    validation_epoch_scores = model_performances(np.array(all_labels), np.array(all_outputs),
                                                 running_loss / mini_batch_counter, validation_epoch_scores)

    return validation_epoch_scores

# %% [markdown]
# ## Paramètres de test

# %%
# model_name = "CNN"
model_name = "VGG"

dataset_path = "data"

results_path = "./results"
results_path = results_path + "_" + model_name

# Define the number of epochs of the model training
epoch_number = 20

# Define the size of the mini-batch
batch_size = 64

# Define the learning rate
learning_rate = 0.005

weight_decay = 0.001

# %% [markdown]
# ## Create logs

# %%
# Get the date and time
now = datetime.now()
# Create the folder name
my_folder_name = now.strftime("%Y-%m-%d_%H" + "h" + "%M" + "min" + "%S" + "sec")
# Create the folder
os.makedirs(os.path.join(results_path, my_folder_name))
# Print a message in the console
print("\nResult folder created")

# Create and open a txt file to store information about the model performances
txt_file = open(os.path.join(os.path.join(results_path, my_folder_name), "Results.txt"), "a")

# Write information about hyperparameters
print_txt("Hyperparameters", txt_file)
print_txt(f"Model name: {model_name}", txt_file)
print_txt(f"Epoch number: {epoch_number}", txt_file)
print_txt(f"Batch size: {batch_size}", txt_file)
print_txt(f"Learning rate: {learning_rate}", txt_file)
print_txt(f"Weight decay: {weight_decay}", txt_file)
# Out:
# Result folder created
# Hyperparameters
# Model name: VGG
# Epoch number: 20
# Batch size: 64
# Learning rate: 0.005
# Weight decay: 0.001

# %% [markdown]
# ## Load dataset

# %%
""" Data Transformation """

if model_name == "CNN":
    transform = transforms.Compose([
        transforms.Resize((240, 240)),
        transforms.ToTensor(),
    ])
elif model_name == "VGG":
    transform = transforms.Compose([
        transforms.Resize((256,256)),
        transforms.ToTensor(),
    ])

target_transform = transforms.Compose([
    transforms.Lambda(
        lambda y: torch.zeros(53, dtype=torch.float).scatter_(0, torch.tensor(y), value=1)
    )
])

# %%
""" Load dataset """

train_dataset = torchvision.datasets.ImageFolder(
    dataset_path + "/train",
    transform=transform,
    target_transform=target_transform
)

validation_dataset = torchvision.datasets.ImageFolder(
    dataset_path + "/valid",
    transform=transform,
    target_transform=target_transform
)

test_dataset = torchvision.datasets.ImageFolder(
    dataset_path + "/test",
    transform=transform,
    target_transform=target_transform
)

# %%
""" Create data loader """

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True
)

validation_loader = torch.utils.data.DataLoader(
    validation_dataset,
    batch_size=batch_size,
    shuffle=False
)

test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False
)

# %%
""" Get data informations """

# Load the first batch of images from the train set
images, labels = next(iter(train_loader))

# Get the shape of the images
image_shape = list(images.data.shape)
# Get automatically the number of channels of images
image_channel = image_shape[1]

# Get the number of classes from the dataset
classes = train_dataset.classes
class_number = len(list(classes))

# %% [markdown]
# ## Création du model

# %%
# Check if GPU is available and set the device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Instantiate the model
if model_name == "CNN":
    model = CNNClassifier(in_channel=image_channel, output_dim=class_number)

elif model_name == "VGG":
    model = models.vgg19(weights=models.VGG19_Weights.IMAGENET1K_V1)

    # Geler tous les poids de vgg
    for param in model.parameters():
        param.requires_grad = False

    model.classifier[6] = nn.Linear(4096, class_number)

# move the model to GPU
model = model.to(device)

# Print information about the model
get_model_information(model, txt_file)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=53, bias=True)
#   )
# )
# Total parameters: 139787381
# Trainable parameters: 217141

# %% [markdown]
# ## Optimizer and loss function

# %%
# Create the loss function
loss_function = nn.CrossEntropyLoss()
# Create the optimizer
optimizer = optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# %% [markdown]
# ## Training

# %%
# Train the neural network
model = train_model(
    epoch_number,
    train_loader,
    validation_loader,
    model, optimizer,
    loss_function,
    device,
    results_path,
    my_folder_name
)
# Out:
# Epoch 1/20: 100%|██████████| 120/120 [01:20<00:00,  1.49 mini-batch/s, train_accuracy=22.6, train_loss=3.45]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.83 mini-batch/s, validation_accuracy=28.2, validation_loss=2.53]
# Epoch 2/20: 100%|██████████| 120/120 [01:19<00:00,  1.50 mini-batch/s, train_accuracy=43.8, train_loss=2.02]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.85 mini-batch/s, validation_accuracy=36.9, validation_loss=2.11]
# Epoch 3/20: 100%|██████████| 120/120 [01:19<00:00,  1.51 mini-batch/s, train_accuracy=55.5, train_loss=1.52]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.73 mini-batch/s, validation_accuracy=46.7, validation_loss=2.24]
# Epoch 4/20: 100%|██████████| 120/120 [01:19<00:00,  1.50 mini-batch/s, train_accuracy=63.7, train_loss=1.22]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.83 mini-batch/s, validation_accuracy=50.2, validation_loss=1.84]
# Epoch 5/20: 100%|██████████| 120/120 [01:19<00:00,  1.51 mini-batch/s, train_accuracy=70.1, train_loss=0.967]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.78 mini-batch/s, validation_accuracy=45.1, validation_loss=2.06]
# Epoch 6/20: 100%|██████████| 120/120 [01:19<00:00,  1.51 mini-batch/s, train_accuracy=77.1, train_loss=0.758]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.86 mini-batch/s, validation_accuracy=49.6, validation_loss=1.99]
# Epoch 7/20: 100%|██████████| 120/120 [01:20<00:00,  1.50 mini-batch/s, train_accuracy=80.8, train_loss=0.639]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.85 mini-batch/s, validation_accuracy=48.9, validation_loss=2.19]
# Epoch 8/20: 100%|██████████| 120/120 [01:19<00:00,  1.51 mini-batch/s, train_accuracy=82.8, train_loss=0.575]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.69 mini-batch/s, validation_accuracy=56.5, validation_loss=1.84]
# Epoch 9/20: 100%|██████████| 120/120 [01:19<00:00,  1.51 mini-batch/s, train_accuracy=86.6, train_loss=0.456]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.85 mini-batch/s, validation_accuracy=58.4, validation_loss=1.74]
# Epoch 10/20: 100%|██████████| 120/120 [01:19<00:00,  1.50 mini-batch/s, train_accuracy=89, train_loss=0.391]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.84 mini-batch/s, validation_accuracy=51.7, validation_loss=1.94]
# Epoch 11/20: 100%|██████████| 120/120 [01:19<00:00,  1.51 mini-batch/s, train_accuracy=91.9, train_loss=0.312]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.68 mini-batch/s, validation_accuracy=57.7, validation_loss=1.79]
# Epoch 12/20: 100%|██████████| 120/120 [01:19<00:00,  1.51 mini-batch/s, train_accuracy=92.4, train_loss=0.295]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.84 mini-batch/s, validation_accuracy=58, validation_loss=1.76]
# Epoch 13/20: 100%|██████████| 120/120 [01:19<00:00,  1.50 mini-batch/s, train_accuracy=94.6, train_loss=0.243]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.85 mini-batch/s, validation_accuracy=58.4, validation_loss=1.74]
# Epoch 14/20: 100%|██████████| 120/120 [01:19<00:00,  1.51 mini-batch/s, train_accuracy=94.4, train_loss=0.226]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.73 mini-batch/s, validation_accuracy=58.3, validation_loss=1.8]
# Epoch 15/20: 100%|██████████| 120/120 [01:19<00:00,  1.50 mini-batch/s, train_accuracy=93.8, train_loss=0.243]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.80 mini-batch/s, validation_accuracy=50.7, validation_loss=2.05]
# Epoch 16/20: 100%|██████████| 120/120 [01:20<00:00,  1.50 mini-batch/s, train_accuracy=95.2, train_loss=0.204]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.72 mini-batch/s, validation_accuracy=57.7, validation_loss=1.94]
# Epoch 17/20: 100%|██████████| 120/120 [01:19<00:00,  1.51 mini-batch/s, train_accuracy=96.1, train_loss=0.17]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.83 mini-batch/s, validation_accuracy=57.4, validation_loss=1.9]
# Epoch 18/20: 100%|██████████| 120/120 [01:19<00:00,  1.51 mini-batch/s, train_accuracy=96.2, train_loss=0.166]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.85 mini-batch/s, validation_accuracy=57.4, validation_loss=2.03]
# Epoch 19/20: 100%|██████████| 120/120 [01:19<00:00,  1.51 mini-batch/s, train_accuracy=97.9, train_loss=0.122]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.72 mini-batch/s, validation_accuracy=54.9, validation_loss=2.02]
# Epoch 20/20: 100%|██████████| 120/120 [01:19<00:00,  1.50 mini-batch/s, train_accuracy=97.2, train_loss=0.133]
#                Validation step: 100%|██████████| 5/5 [00:02<00:00,  1.84 mini-batch/s, validation_accuracy=56.1, validation_loss=1.86]

# %%
# Test the neural network
test_model(
    test_loader,
    model,
    loss_function,
    device,
    classes,
    txt_file
)
# Out:
# Testing the training model: 100%|██████████| 5/5 [00:02<00:00,  1.85 mini-batch/s, testing_accuracy=47.9, testing_loss=3.17]
# Accuracy: 0.5320754716981132
# Balanced Accuracy: 0.5320754716981132
# F1-score: 0.5320754716981132
# Kappa: 0.523076923076923
#                    precision    recall  f1-score   support
#
#      ace of clubs       0.60      0.60      0.60         5
#   ace of diamonds       0.83      1.00      0.91         5
#     ace of hearts       1.00      1.00      1.00         5
#     ace of spades       1.00      1.00      1.00         5
#    eight of clubs       0.29      0.40      0.33         5
# eight of diamonds       0.40      0.40      0.40         5
#   eight of hearts       0.62      1.00      0.77         5
#   eight of spades       0.00      0.00      0.00         5
#     five of clubs       0.29      0.40      0.33         5
#  five of diamonds       0.43      0.60      0.50         5
#    five of hearts       0.40      0.40      0.40         5
#    five of spades       0.50      0.20      0.29         5
#     four of clubs       0.50      0.60      0.55         5
#  four of diamonds       1.00      0.40      0.57         5
#    four of hearts       1.00      0.60      0.75         5
#    four of spades       0.22      0.40      0.29         5
#     jack of clubs       0.83      1.00      0.91         5
#  jack of diamonds       0.75      0.60      0.67         5
#    jack of hearts       0.50      0.80      0.62         5
#    jack of spades       0.40      0.40      0.40         5
#             joker       0.00      0.00      0.00         5
#     king of clubs       0.75      0.60      0.67         5
#  king of diamonds       0.29      0.40      0.33         5
#    king of hearts       0.60      0.60      0.60         5
#    king of spades       1.00      0.60      0.75         5
#     nine of clubs       0.67      0.40      0.50         5
#  nine of diamonds       0.50      0.60      0.55         5
#    nine of hearts       0.33      0.60      0.43         5
#    nine of spades       0.50      0.60      0.55         5
#    queen of clubs       1.00      0.40      0.57         5
# queen of diamonds       0.50      0.80      0.62         5
#   queen of hearts       0.50      0.40      0.44         5
#   queen of spades       0.67      0.80      0.73         5
#    seven of clubs       1.00      0.40      0.57         5
# seven of diamonds       0.33      0.60      0.43         5
#   seven of hearts       1.00      0.40      0.57         5
#   seven of spades       0.50      0.60      0.55         5
#      six of clubs       0.25      0.20      0.22         5
#   six of diamonds       0.33      0.20      0.25         5
#     six of hearts       0.40      0.40      0.40         5
#     six of spades       0.50      1.00      0.67         5
#      ten of clubs       1.00      0.40      0.57         5
#   ten of diamonds       0.67      0.40      0.50         5
#     ten of hearts       1.00      0.60      0.75         5
#     ten of spades       0.50      0.60      0.55         5
#    three of clubs       0.30      0.60      0.40         5
# three of diamonds       0.50      0.20      0.29         5
#   three of hearts       0.75      0.60      0.67         5
#   three of spades       0.44      0.80      0.57         5
#      two of clubs       1.00      0.20      0.33         5
#   two of diamonds       0.80      0.80      0.80         5
#     two of hearts       0.25      0.40      0.31         5
#     two of spades       1.00      0.20      0.33         5
#
#          accuracy                           0.53       265
#         macro avg       0.59      0.53      0.52       265
#      weighted avg       0.59      0.53      0.52       265
#
# Top 2 Accuracy: 0.6490566037735849
# Top 3 Accuracy: 0.7132075471698113
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#        Loss  Accuracy  Balanced Accuracy  F1-score     Kappa  Top 2 Accuracy  \
# 0  3.166297  0.532075           0.532075  0.532075  0.523077        0.649057
#
#    Top 3 Accuracy
# 0        0.713208

# %%
# Close your txt file
txt_file.close()
